# %%
from tensorflow.keras.applications import Xception, ResNet50, DenseNet121, VGG16

# Load each pre-trained model
xception_model = Xception(weights='imagenet', include_top=False, input_shape=(224, 224, 3))
resnet_model = ResNet50(weights='imagenet', include_top=False, input_shape=(224, 224, 3))
densenet_model = DenseNet121(weights='imagenet', include_top=False, input_shape=(224, 224, 3))
vgg16_model = VGG16(weights='imagenet', include_top=False, input_shape=(224, 224, 3))

# Print the summary of each model
print("Xception Model Summary")
xception_model.summary()

print("\nResNet Model Summary")
resnet_model.summary()

print("\nDenseNet Model Summary")
densenet_model.summary()

print("\nVGG16 Model Summary")
vgg16_model.summary()
# Out:
# Xception Model Summary
# Model: "xception"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                  ┃ Output Shape              ┃         Param # ┃ Connected to               ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━┩
# │ input_layer_4 (InputLayer)    │ (None, 224, 224, 3)       │               0 │ -                          │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block1_conv1 (Conv2D)         │ (None, 111, 111, 32)      │             864 │ input_layer_4[0][0]        │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block1_conv1_bn               │ (None, 111, 111, 32)      │             128 │ block1_conv1[0][0]         │
# ...

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, roc_curve, auc, confusion_matrix
from tensorflow.keras.models import load_model
from tensorflow.keras.applications import Xception, ResNet50, DenseNet121, VGG16

# Load your models
model_xception = load_model('path_to_your_xception_model.h5')
model_densenet = load_model('path_to_your_densenet_model.h5')
model_resnet = load_model('path_to_your_resnet_model.h5')
model_vgg16 = load_model('path_to_your_vgg16_model.h5')

# Load your test data (images and labels)
# Assuming you have a function or a generator that loads your test images and labels
test_images, y_true = load_test_data()  # Implement this function based on your data

# Make predictions
y_pred_prob_xception = model_xception.predict(test_images)
y_pred_prob_densenet = model_densenet.predict(test_images)
y_pred_prob_resnet = model_resnet.predict(test_images)
y_pred_prob_vgg16 = model_vgg16.predict(test_images)

# Convert probabilities to binary predictions (assuming binary classification)
y_pred_xception = (y_pred_prob_xception > 0.5).astype(int)
y_pred_densenet = (y_pred_prob_densenet > 0.5).astype(int)
y_pred_resnet = (y_pred_prob_resnet > 0.5).astype(int)
y_pred_vgg16 = (y_pred_prob_vgg16 > 0.5).astype(int)

# Calculate metrics
models = ['Xception', 'DenseNet', 'ResNet', 'VGG16']
y_preds = [y_pred_xception, y_pred_densenet, y_pred_resnet, y_pred_vgg16]
y_probs = [y_pred_prob_xception, y_pred_prob_densenet, y_pred_prob_resnet, y_pred_prob_vgg16]

metrics = {
    "Model": models,
    "Accuracy": [],
    "Precision": [],
    "Recall": [],
    "F1 Score": []
}

for y_pred in y_preds:
    metrics["Accuracy"].append(accuracy_score(y_true, y_pred))
    metrics["Precision"].append(precision_score(y_true, y_pred, average='binary'))
    metrics["Recall"].append(recall_score(y_true, y_pred, average='binary'))
    metrics["F1 Score"].append(f1_score(y_true, y_pred, average='binary'))

# Create DataFrame
metrics_df = pd.DataFrame(metrics)

# Display metrics table
print(metrics_df)

# Plot ROC curves
plt.figure(figsize=(10, 8))
for i, (model, y_prob) in enumerate(zip(models, y_probs)):
    fpr, tpr, _ = roc_curve(y_true, y_prob)
    roc_auc = auc(fpr, tpr)
    plt.plot(fpr, tpr, lw=2, label=f'{model} (AUC = {roc_auc:.2f})')

plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic (ROC) Curves')
plt.legend(loc="lower right")
plt.show()

# Plot confusion matrices
fig, axes = plt.subplots(2, 2, figsize=(12, 10))
axes = axes.ravel()

for i, (model, y_pred) in enumerate(zip(models, y_preds)):
    cm = confusion_matrix(y_true, y_pred)
    sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', ax=axes[i])
    axes[i].set_title(f'{model} Confusion Matrix')
    axes[i].set_xlabel('Predicted Label')
    axes[i].set_ylabel('True Label')

plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[1], line 9
#       6 from tensorflow.keras.applications import Xception, ResNet50, DenseNet121, VGG16
#       8 # Load your models
# ----> 9 model_xception = load_model('path_to_your_xception_model.h5')
#      10 model_densenet = load_model('path_to_your_densenet_model.h5')
#      11 model_resnet = load_model('path_to_your_resnet_model.h5')
#
# File ~\AppData\Roaming\Python\Python311\site-packages\keras\src\saving\saving_api.py:183, in load_model(filepath, custom_objects, compile, safe_mode)
#     176     return saving_lib.load_model(
#     177         filepath,
#     178         custom_objects=custom_objects,
#     179         compile=compile,
#     180         safe_mode=safe_mode,
#     181     )
#     182 if str(filepath).endswith((".h5", ".hdf5")):
# --> 183     return legacy_h5_format.load_model_from_hdf5(filepath)
# ...
